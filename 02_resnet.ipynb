# %% [markdown]
# # Tensorflow ResNet

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
from typing import List

# %%
def residual_block(tensor, name: str, filters: int, strides: tuple = (1, 1), is_conv_shortcut: bool = True):
    """A residual block.
    Args:
        tensor: input tensor
        name: string, block label.
        filters: integer, filters of the bottleneck layer.
        strides: default 1, stride of the first layer and shortcut layer.
        conv_shortcut: default True, use convolution shortcut if True, otherwise identity shortcut.
    Returns:
        Output tensor for the residual block.
    """

    shortcut = tensor
    if is_conv_shortcut:
        shortcut = tf.keras.layers.Conv2D(
            name=f"{name}x0_SC_Conv", filters=4*filters, kernel_size=(1, 1), strides=strides, padding='VALID')(tensor)
        shortcut = tf.keras.layers.BatchNormalization(
            name=f"{name}x0_SC_BN")(shortcut)

    # 1st Conv
    out = tf.keras.layers.Conv2D(name=f"{name}x1_Conv", filters=filters, kernel_size=(
        1, 1), strides=strides, padding='VALID')(tensor)
    out = tf.keras.layers.BatchNormalization(name=f"{name}x1_BN")(out)
    out = tf.keras.layers.ReLU(name=f"{name}x1_ReLU")(out)

    # 2nd Conv
    out = tf.keras.layers.Conv2D(name=f"{name}x2_Conv", filters=filters, kernel_size=(
        3, 3), strides=(1, 1), padding='SAME')(out)
    out = tf.keras.layers.BatchNormalization(name=f"{name}x2_BN")(out)
    out = tf.keras.layers.ReLU(name=f"{name}x2_ReLU")(out)

    # 3rd Conv
    out = tf.keras.layers.Conv2D(
        name=f"{name}x3_Conv", filters=4*filters, kernel_size=(1, 1), strides=(1, 1), padding='VALID')(out)
    out = tf.keras.layers.BatchNormalization(name=f"{name}x3_BN")(out)

    # Connection
    out = tf.keras.layers.Add(name=f"{name}x3_Add")([shortcut, out])
    out = tf.keras.layers.ReLU(name=f"{name}x3_ReLU")(out)

    return out

# %%
def residual_stack(tensor, filters: int, num_blocks: int, is_first_block: bool = False, name=None):
    """A set of stacked residual blocks.
    Args:
        tensor: input tensor
        filters: integer, filters of the bottleneck layer in a block.
        num_blocks: integer, blocks in the stacked blocks.
        name: string, stack label.
    Returns:
        Output tensor for the stacked blocks.
    """

    if is_first_block:
        out = residual_block(tensor=tensor, name=f"{name}_1", filters=filters)
    else:
        out = residual_block(
            tensor=tensor, name=f"{name}_1", filters=filters, strides=(2, 2))

    for i in range(2, num_blocks+1):
        out = residual_block(tensor=out, name=name + "_" +
                             str(i), filters=filters, is_conv_shortcut=False)

    return out

# %%
def ResNet(name, blocks: List[int], num_classes: int):
    def stack_fn(tensor):
        out = tf.keras.layers.Conv2D(name="Head_Conv", filters=64, kernel_size=(
            7, 7), strides=(2, 2), padding="same")(tensor)
        out = tf.keras.layers.MaxPool2D(name="Head_MaxPool", pool_size=(
            3, 3), strides=(2, 2), padding="same")(out)
        out = residual_stack(tensor=out, name="Stack1",
                             is_first_block=True, filters=64, num_blocks=blocks[0])
        out = residual_stack(tensor=out, name="Stack2",
                             filters=128, num_blocks=blocks[1])
        out = residual_stack(tensor=out, name="Stack3",
                             filters=256, num_blocks=blocks[2])
        out = residual_stack(tensor=out, name="Stack4",
                             filters=512, num_blocks=blocks[3])
        out = tf.keras.layers.GlobalAveragePooling2D(
            name="Tail_GlobalAVGPool")(out)
        out = tf.keras.layers.Flatten(name="Tail_Flatten")(out)
        out = tf.keras.layers.Dense(
            name="Tail_Dense", units=num_classes, activation='softmax')(out)
        return out

    x = tf.keras.layers.Input(name="Head_Input", shape=(224, 224, 3))
    model = tf.keras.models.Model(name=name, inputs=[x], outputs=stack_fn(x))
    return model

# %%
resnet_101 = ResNet(name="ResNet101", blocks=[3, 4, 23, 3], num_classes=1000)
resnet_101.summary()
# Out:
# Model: "ResNet101"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Head_Input (InputLayer)        [(None, 224, 224, 3  0           []
#                                 )]
#
#  Head_Conv (Conv2D)             (None, 112, 112, 64  9472        ['Head_Input[0][0]']
#                                 )
#
#  Head_MaxPool (MaxPooling2D)    (None, 56, 56, 64)   0           ['Head_Conv[0][0]']
#
#  Stack1_1x1_Conv (Conv2D)       (None, 56, 56, 64)   4160        ['Head_MaxPool[0][0]']
#
#  Stack1_1x1_BN (BatchNormalizat  (None, 56, 56, 64)  256         ['Stack1_1x1_Conv[0][0]']
#  ion)
#
#  Stack1_1x1_ReLU (ReLU)         (None, 56, 56, 64)   0           ['Stack1_1x1_BN[0][0]']
#
#  Stack1_1x2_Conv (Conv2D)       (None, 56, 56, 64)   36928       ['Stack1_1x1_ReLU[0][0]']
#
#  Stack1_1x2_BN (BatchNormalizat  (None, 56, 56, 64)  256         ['Stack1_1x2_Conv[0][0]']
#  ion)
#
#  Stack1_1x2_ReLU (ReLU)         (None, 56, 56, 64)   0           ['Stack1_1x2_BN[0][0]']
#
#  Stack1_1x0_SC_Conv (Conv2D)    (None, 56, 56, 256)  16640       ['Head_MaxPool[0][0]']
#
#  Stack1_1x3_Conv (Conv2D)       (None, 56, 56, 256)  16640       ['Stack1_1x2_ReLU[0][0]']
#
#  Stack1_1x0_SC_BN (BatchNormali  (None, 56, 56, 256)  1024       ['Stack1_1x0_SC_Conv[0][0]']
#  zation)
#
#  Stack1_1x3_BN (BatchNormalizat  (None, 56, 56, 256)  1024       ['Stack1_1x3_Conv[0][0]']
#  ion)
#
#  Stack1_1x3_Add (Add)           (None, 56, 56, 256)  0           ['Stack1_1x0_SC_BN[0][0]',
#                                                                   'Stack1_1x3_BN[0][0]']
#
#  Stack1_1x3_ReLU (ReLU)         (None, 56, 56, 256)  0           ['Stack1_1x3_Add[0][0]']
#
#  Stack1_2x1_Conv (Conv2D)       (None, 56, 56, 64)   16448       ['Stack1_1x3_ReLU[0][0]']
#
#  Stack1_2x1_BN (BatchNormalizat  (None, 56, 56, 64)  256         ['Stack1_2x1_Conv[0][0]']
#  ion)
#
#  Stack1_2x1_ReLU (ReLU)         (None, 56, 56, 64)   0           ['Stack1_2x1_BN[0][0]']
#
#  Stack1_2x2_Conv (Conv2D)       (None, 56, 56, 64)   36928       ['Stack1_2x1_ReLU[0][0]']
#
#  Stack1_2x2_BN (BatchNormalizat  (None, 56, 56, 64)  256         ['Stack1_2x2_Conv[0][0]']
#  ion)
#
#  Stack1_2x2_ReLU (ReLU)         (None, 56, 56, 64)   0           ['Stack1_2x2_BN[0][0]']
#
#  Stack1_2x3_Conv (Conv2D)       (None, 56, 56, 256)  16640       ['Stack1_2x2_ReLU[0][0]']
#
#  Stack1_2x3_BN (BatchNormalizat  (None, 56, 56, 256)  1024       ['Stack1_2x3_Conv[0][0]']
#  ion)
#
#  Stack1_2x3_Add (Add)           (None, 56, 56, 256)  0           ['Stack1_1x3_ReLU[0][0]',
#                                                                   'Stack1_2x3_BN[0][0]']
#
#  Stack1_2x3_ReLU (ReLU)         (None, 56, 56, 256)  0           ['Stack1_2x3_Add[0][0]']
#
#  Stack1_3x1_Conv (Conv2D)       (None, 56, 56, 64)   16448       ['Stack1_2x3_ReLU[0][0]']
#
#  Stack1_3x1_BN (BatchNormalizat  (None, 56, 56, 64)  256         ['Stack1_3x1_Conv[0][0]']
#  ion)
#
#  Stack1_3x1_ReLU (ReLU)         (None, 56, 56, 64)   0           ['Stack1_3x1_BN[0][0]']
#
#  Stack1_3x2_Conv (Conv2D)       (None, 56, 56, 64)   36928       ['Stack1_3x1_ReLU[0][0]']
#
#  Stack1_3x2_BN (BatchNormalizat  (None, 56, 56, 64)  256         ['Stack1_3x2_Conv[0][0]']
#  ion)
#
#  Stack1_3x2_ReLU (ReLU)         (None, 56, 56, 64)   0           ['Stack1_3x2_BN[0][0]']
#
#  Stack1_3x3_Conv (Conv2D)       (None, 56, 56, 256)  16640       ['Stack1_3x2_ReLU[0][0]']
#
#  Stack1_3x3_BN (BatchNormalizat  (None, 56, 56, 256)  1024       ['Stack1_3x3_Conv[0][0]']
#  ion)
#
#  Stack1_3x3_Add (Add)           (None, 56, 56, 256)  0           ['Stack1_2x3_ReLU[0][0]',
#                                                                   'Stack1_3x3_BN[0][0]']
#
#  Stack1_3x3_ReLU (ReLU)         (None, 56, 56, 256)  0           ['Stack1_3x3_Add[0][0]']
#
#  Stack2_1x1_Conv (Conv2D)       (None, 28, 28, 128)  32896       ['Stack1_3x3_ReLU[0][0]']
#
#  Stack2_1x1_BN (BatchNormalizat  (None, 28, 28, 128)  512        ['Stack2_1x1_Conv[0][0]']
#  ion)
#
#  Stack2_1x1_ReLU (ReLU)         (None, 28, 28, 128)  0           ['Stack2_1x1_BN[0][0]']
#
#  Stack2_1x2_Conv (Conv2D)       (None, 28, 28, 128)  147584      ['Stack2_1x1_ReLU[0][0]']
#
#  Stack2_1x2_BN (BatchNormalizat  (None, 28, 28, 128)  512        ['Stack2_1x2_Conv[0][0]']
#  ion)
#
#  Stack2_1x2_ReLU (ReLU)         (None, 28, 28, 128)  0           ['Stack2_1x2_BN[0][0]']
#
#  Stack2_1x0_SC_Conv (Conv2D)    (None, 28, 28, 512)  131584      ['Stack1_3x3_ReLU[0][0]']
#
#  Stack2_1x3_Conv (Conv2D)       (None, 28, 28, 512)  66048       ['Stack2_1x2_ReLU[0][0]']
#
#  Stack2_1x0_SC_BN (BatchNormali  (None, 28, 28, 512)  2048       ['Stack2_1x0_SC_Conv[0][0]']
#  zation)
#
#  Stack2_1x3_BN (BatchNormalizat  (None, 28, 28, 512)  2048       ['Stack2_1x3_Conv[0][0]']
#  ion)
#
#  Stack2_1x3_Add (Add)           (None, 28, 28, 512)  0           ['Stack2_1x0_SC_BN[0][0]',
#                                                                   'Stack2_1x3_BN[0][0]']
#
#  Stack2_1x3_ReLU (ReLU)         (None, 28, 28, 512)  0           ['Stack2_1x3_Add[0][0]']
#
#  Stack2_2x1_Conv (Conv2D)       (None, 28, 28, 128)  65664       ['Stack2_1x3_ReLU[0][0]']
#
#  Stack2_2x1_BN (BatchNormalizat  (None, 28, 28, 128)  512        ['Stack2_2x1_Conv[0][0]']
#  ion)
#
#  Stack2_2x1_ReLU (ReLU)         (None, 28, 28, 128)  0           ['Stack2_2x1_BN[0][0]']
#
#  Stack2_2x2_Conv (Conv2D)       (None, 28, 28, 128)  147584      ['Stack2_2x1_ReLU[0][0]']
#
#  Stack2_2x2_BN (BatchNormalizat  (None, 28, 28, 128)  512        ['Stack2_2x2_Conv[0][0]']
#  ion)
#
#  Stack2_2x2_ReLU (ReLU)         (None, 28, 28, 128)  0           ['Stack2_2x2_BN[0][0]']
#
#  Stack2_2x3_Conv (Conv2D)       (None, 28, 28, 512)  66048       ['Stack2_2x2_ReLU[0][0]']
#
#  Stack2_2x3_BN (BatchNormalizat  (None, 28, 28, 512)  2048       ['Stack2_2x3_Conv[0][0]']
#  ion)
#
#  Stack2_2x3_Add (Add)           (None, 28, 28, 512)  0           ['Stack2_1x3_ReLU[0][0]',
#                                                                   'Stack2_2x3_BN[0][0]']
#
#  Stack2_2x3_ReLU (ReLU)         (None, 28, 28, 512)  0           ['Stack2_2x3_Add[0][0]']
#
#  Stack2_3x1_Conv (Conv2D)       (None, 28, 28, 128)  65664       ['Stack2_2x3_ReLU[0][0]']
#
#  Stack2_3x1_BN (BatchNormalizat  (None, 28, 28, 128)  512        ['Stack2_3x1_Conv[0][0]']
#  ion)
#
#  Stack2_3x1_ReLU (ReLU)         (None, 28, 28, 128)  0           ['Stack2_3x1_BN[0][0]']
#
#  Stack2_3x2_Conv (Conv2D)       (None, 28, 28, 128)  147584      ['Stack2_3x1_ReLU[0][0]']
#
#  Stack2_3x2_BN (BatchNormalizat  (None, 28, 28, 128)  512        ['Stack2_3x2_Conv[0][0]']
#  ion)
#
#  Stack2_3x2_ReLU (ReLU)         (None, 28, 28, 128)  0           ['Stack2_3x2_BN[0][0]']
#
#  Stack2_3x3_Conv (Conv2D)       (None, 28, 28, 512)  66048       ['Stack2_3x2_ReLU[0][0]']
#
#  Stack2_3x3_BN (BatchNormalizat  (None, 28, 28, 512)  2048       ['Stack2_3x3_Conv[0][0]']
#  ion)
#
#  Stack2_3x3_Add (Add)           (None, 28, 28, 512)  0           ['Stack2_2x3_ReLU[0][0]',
#                                                                   'Stack2_3x3_BN[0][0]']
#
#  Stack2_3x3_ReLU (ReLU)         (None, 28, 28, 512)  0           ['Stack2_3x3_Add[0][0]']
#
#  Stack2_4x1_Conv (Conv2D)       (None, 28, 28, 128)  65664       ['Stack2_3x3_ReLU[0][0]']
#
#  Stack2_4x1_BN (BatchNormalizat  (None, 28, 28, 128)  512        ['Stack2_4x1_Conv[0][0]']
#  ion)
#
#  Stack2_4x1_ReLU (ReLU)         (None, 28, 28, 128)  0           ['Stack2_4x1_BN[0][0]']
#
#  Stack2_4x2_Conv (Conv2D)       (None, 28, 28, 128)  147584      ['Stack2_4x1_ReLU[0][0]']
#
#  Stack2_4x2_BN (BatchNormalizat  (None, 28, 28, 128)  512        ['Stack2_4x2_Conv[0][0]']
#  ion)
#
#  Stack2_4x2_ReLU (ReLU)         (None, 28, 28, 128)  0           ['Stack2_4x2_BN[0][0]']
#
#  Stack2_4x3_Conv (Conv2D)       (None, 28, 28, 512)  66048       ['Stack2_4x2_ReLU[0][0]']
#
#  Stack2_4x3_BN (BatchNormalizat  (None, 28, 28, 512)  2048       ['Stack2_4x3_Conv[0][0]']
#  ion)
#
#  Stack2_4x3_Add (Add)           (None, 28, 28, 512)  0           ['Stack2_3x3_ReLU[0][0]',
#                                                                   'Stack2_4x3_BN[0][0]']
#
#  Stack2_4x3_ReLU (ReLU)         (None, 28, 28, 512)  0           ['Stack2_4x3_Add[0][0]']
#
#  Stack3_1x1_Conv (Conv2D)       (None, 14, 14, 256)  131328      ['Stack2_4x3_ReLU[0][0]']
#
#  Stack3_1x1_BN (BatchNormalizat  (None, 14, 14, 256)  1024       ['Stack3_1x1_Conv[0][0]']
#  ion)
#
#  Stack3_1x1_ReLU (ReLU)         (None, 14, 14, 256)  0           ['Stack3_1x1_BN[0][0]']
#
#  Stack3_1x2_Conv (Conv2D)       (None, 14, 14, 256)  590080      ['Stack3_1x1_ReLU[0][0]']
#
#  Stack3_1x2_BN (BatchNormalizat  (None, 14, 14, 256)  1024       ['Stack3_1x2_Conv[0][0]']
#  ion)
#
#  Stack3_1x2_ReLU (ReLU)         (None, 14, 14, 256)  0           ['Stack3_1x2_BN[0][0]']
#
#  Stack3_1x0_SC_Conv (Conv2D)    (None, 14, 14, 1024  525312      ['Stack2_4x3_ReLU[0][0]']
#                                 )
#
#  Stack3_1x3_Conv (Conv2D)       (None, 14, 14, 1024  263168      ['Stack3_1x2_ReLU[0][0]']
#                                 )
#
#  Stack3_1x0_SC_BN (BatchNormali  (None, 14, 14, 1024  4096       ['Stack3_1x0_SC_Conv[0][0]']
#  zation)                        )
#
#  Stack3_1x3_BN (BatchNormalizat  (None, 14, 14, 1024  4096       ['Stack3_1x3_Conv[0][0]']
#  ion)                           )
#
#  Stack3_1x3_Add (Add)           (None, 14, 14, 1024  0           ['Stack3_1x0_SC_BN[0][0]',
#                                 )                                 'Stack3_1x3_BN[0][0]']
#
#  Stack3_1x3_ReLU (ReLU)         (None, 14, 14, 1024  0           ['Stack3_1x3_Add[0][0]']
#                                 )
#
#  Stack3_2x1_Conv (Conv2D)       (None, 14, 14, 256)  262400      ['Stack3_1x3_ReLU[0][0]']
#
#  Stack3_2x1_BN (BatchNormalizat  (None, 14, 14, 256)  1024       ['Stack3_2x1_Conv[0][0]']
#  ion)
#
#  Stack3_2x1_ReLU (ReLU)         (None, 14, 14, 256)  0           ['Stack3_2x1_BN[0][0]']
#
#  Stack3_2x2_Conv (Conv2D)       (None, 14, 14, 256)  590080      ['Stack3_2x1_ReLU[0][0]']
#
#  Stack3_2x2_BN (BatchNormalizat  (None, 14, 14, 256)  1024       ['Stack3_2x2_Conv[0][0]']
#  ion)
#
#  Stack3_2x2_ReLU (ReLU)         (None, 14, 14, 256)  0           ['Stack3_2x2_BN[0][0]']
#
#  Stack3_2x3_Conv (Conv2D)       (None, 14, 14, 1024  263168      ['Stack3_2x2_ReLU[0][0]']
#                                 )
#
#  Stack3_2x3_BN (BatchNormalizat  (None, 14, 14, 1024  4096       ['Stack3_2x3_Conv[0][0]']
#  ion)                           )
#
#  Stack3_2x3_Add (Add)           (None, 14, 14, 1024  0           ['Stack3_1x3_ReLU[0][0]',
#                                 )                                 'Stack3_2x3_BN[0][0]']
#
#  Stack3_2x3_ReLU (ReLU)         (None, 14, 14, 1024  0           ['Stack3_2x3_Add[0][0]']
#                                 )
#
#  Stack3_3x1_Conv (Conv2D)       (None, 14, 14, 256)  262400      ['Stack3_2x3_ReLU[0][0]']
#
#  Stack3_3x1_BN (BatchNormalizat  (None, 14, 14, 256)  1024       ['Stack3_3x1_Conv[0][0]']
#  ion)
#
#  Stack3_3x1_ReLU (ReLU)         (None, 14, 14, 256)  0           ['Stack3_3x1_BN[0][0]']
#
#  Stack3_3x2_Conv (Conv2D)       (None, 14, 14, 256)  590080      ['Stack3_3x1_ReLU[0][0]']
#
#  Stack3_3x2_BN (BatchNormalizat  (None, 14, 14, 256)  1024       ['Stack3_3x2_Conv[0][0]']
#  ion)
#
#  Stack3_3x2_ReLU (ReLU)         (None, 14, 14, 256)  0           ['Stack3_3x2_BN[0][0]']
#
#  Stack3_3x3_Conv (Conv2D)       (None, 14, 14, 1024  263168      ['Stack3_3x2_ReLU[0][0]']
#                                 )
#
#  Stack3_3x3_BN (BatchNormalizat  (None, 14, 14, 1024  4096       ['Stack3_3x3_Conv[0][0]']
#  ion)                           )
#
#  Stack3_3x3_Add (Add)           (None, 14, 14, 1024  0           ['Stack3_2x3_ReLU[0][0]',
#                                 )                                 'Stack3_3x3_BN[0][0]']
#
#  Stack3_3x3_ReLU (ReLU)         (None, 14, 14, 1024  0           ['Stack3_3x3_Add[0][0]']
#                                 )
#
#  Stack3_4x1_Conv (Conv2D)       (None, 14, 14, 256)  262400      ['Stack3_3x3_ReLU[0][0]']
#
#  Stack3_4x1_BN (BatchNormalizat  (None, 14, 14, 256)  1024       ['Stack3_4x1_Conv[0][0]']
#  ion)
#
#  Stack3_4x1_ReLU (ReLU)         (None, 14, 14, 256)  0           ['Stack3_4x1_BN[0][0]']
#
#  Stack3_4x2_Conv (Conv2D)       (None, 14, 14, 256)  590080      ['Stack3_4x1_ReLU[0][0]']
#
#  Stack3_4x2_BN (BatchNormalizat  (None, 14, 14, 256)  1024       ['Stack3_4x2_Conv[0][0]']
#  ion)
#
#  Stack3_4x2_ReLU (ReLU)         (None, 14, 14, 256)  0           ['Stack3_4x2_BN[0][0]']
#
#  Stack3_4x3_Conv (Conv2D)       (None, 14, 14, 1024  263168      ['Stack3_4x2_ReLU[0][0]']
#                                 )
#
#  Stack3_4x3_BN (BatchNormalizat  (None, 14, 14, 1024  4096       ['Stack3_4x3_Conv[0][0]']
#  ion)                           )
#
#  Stack3_4x3_Add (Add)           (None, 14, 14, 1024  0           ['Stack3_3x3_ReLU[0][0]',
#                                 )                                 'Stack3_4x3_BN[0][0]']
#
#  Stack3_4x3_ReLU (ReLU)         (None, 14, 14, 1024  0           ['Stack3_4x3_Add[0][0]']
#                                 )
#
#  Stack3_5x1_Conv (Conv2D)       (None, 14, 14, 256)  262400      ['Stack3_4x3_ReLU[0][0]']
#
#  Stack3_5x1_BN (BatchNormalizat  (None, 14, 14, 256)  1024       ['Stack3_5x1_Conv[0][0]']
#  ion)
#
#  Stack3_5x1_ReLU (ReLU)         (None, 14, 14, 256)  0           ['Stack3_5x1_BN[0][0]']
#
#  Stack3_5x2_Conv (Conv2D)       (None, 14, 14, 256)  590080      ['Stack3_5x1_ReLU[0][0]']
#
#  Stack3_5x2_BN (BatchNormalizat  (None, 14, 14, 256)  1024       ['Stack3_5x2_Conv[0][0]']
#  ion)
#
#  Stack3_5x2_ReLU (ReLU)         (None, 14, 14, 256)  0           ['Stack3_5x2_BN[0][0]']
#
#  Stack3_5x3_Conv (Conv2D)       (None, 14, 14, 1024  263168      ['Stack3_5x2_ReLU[0][0]']
#                                 )
#
#  Stack3_5x3_BN (BatchNormalizat  (None, 14, 14, 1024  4096       ['Stack3_5x3_Conv[0][0]']
#  ion)                           )
#
#  Stack3_5x3_Add (Add)           (None, 14, 14, 1024  0           ['Stack3_4x3_ReLU[0][0]',
#                                 )                                 'Stack3_5x3_BN[0][0]']
#
#  Stack3_5x3_ReLU (ReLU)         (None, 14, 14, 1024  0           ['Stack3_5x3_Add[0][0]']
#                                 )
#
#  Stack3_6x1_Conv (Conv2D)       (None, 14, 14, 256)  262400      ['Stack3_5x3_ReLU[0][0]']
#
#  Stack3_6x1_BN (BatchNormalizat  (None, 14, 14, 256)  1024       ['Stack3_6x1_Conv[0][0]']
#  ion)
#
#  Stack3_6x1_ReLU (ReLU)         (None, 14, 14, 256)  0           ['Stack3_6x1_BN[0][0]']
#
#  Stack3_6x2_Conv (Conv2D)       (None, 14, 14, 256)  590080      ['Stack3_6x1_ReLU[0][0]']
#
#  Stack3_6x2_BN (BatchNormalizat  (None, 14, 14, 256)  1024       ['Stack3_6x2_Conv[0][0]']
#  ion)
#
#  Stack3_6x2_ReLU (ReLU)         (None, 14, 14, 256)  0           ['Stack3_6x2_BN[0][0]']
#
#  Stack3_6x3_Conv (Conv2D)       (None, 14, 14, 1024  263168      ['Stack3_6x2_ReLU[0][0]']
#                                 )
#
#  Stack3_6x3_BN (BatchNormalizat  (None, 14, 14, 1024  4096       ['Stack3_6x3_Conv[0][0]']
#  ion)                           )
#
#  Stack3_6x3_Add (Add)           (None, 14, 14, 1024  0           ['Stack3_5x3_ReLU[0][0]',
#                                 )                                 'Stack3_6x3_BN[0][0]']
#
#  Stack3_6x3_ReLU (ReLU)         (None, 14, 14, 1024  0           ['Stack3_6x3_Add[0][0]']
#                                 )
#
#  Stack3_7x1_Conv (Conv2D)       (None, 14, 14, 256)  262400      ['Stack3_6x3_ReLU[0][0]']
#
#  Stack3_7x1_BN (BatchNormalizat  (None, 14, 14, 256)  1024       ['Stack3_7x1_Conv[0][0]']
#  ion)
#
#  Stack3_7x1_ReLU (ReLU)         (None, 14, 14, 256)  0           ['Stack3_7x1_BN[0][0]']
#
#  Stack3_7x2_Conv (Conv2D)       (None, 14, 14, 256)  590080      ['Stack3_7x1_ReLU[0][0]']
#
#  Stack3_7x2_BN (BatchNormalizat  (None, 14, 14, 256)  1024       ['Stack3_7x2_Conv[0][0]']
#  ion)
#
#  Stack3_7x2_ReLU (ReLU)         (None, 14, 14, 256)  0           ['Stack3_7x2_BN[0][0]']
#
#  Stack3_7x3_Conv (Conv2D)       (None, 14, 14, 1024  263168      ['Stack3_7x2_ReLU[0][0]']
#                                 )
#
#  Stack3_7x3_BN (BatchNormalizat  (None, 14, 14, 1024  4096       ['Stack3_7x3_Conv[0][0]']
#  ion)                           )
#
#  Stack3_7x3_Add (Add)           (None, 14, 14, 1024  0           ['Stack3_6x3_ReLU[0][0]',
#                                 )                                 'Stack3_7x3_BN[0][0]']
#
#  Stack3_7x3_ReLU (ReLU)         (None, 14, 14, 1024  0           ['Stack3_7x3_Add[0][0]']
#                                 )
#
#  Stack3_8x1_Conv (Conv2D)       (None, 14, 14, 256)  262400      ['Stack3_7x3_ReLU[0][0]']
#
#  Stack3_8x1_BN (BatchNormalizat  (None, 14, 14, 256)  1024       ['Stack3_8x1_Conv[0][0]']
#  ion)
#
#  Stack3_8x1_ReLU (ReLU)         (None, 14, 14, 256)  0           ['Stack3_8x1_BN[0][0]']
#
#  Stack3_8x2_Conv (Conv2D)       (None, 14, 14, 256)  590080      ['Stack3_8x1_ReLU[0][0]']
#
#  Stack3_8x2_BN (BatchNormalizat  (None, 14, 14, 256)  1024       ['Stack3_8x2_Conv[0][0]']
#  ion)
#
#  Stack3_8x2_ReLU (ReLU)         (None, 14, 14, 256)  0           ['Stack3_8x2_BN[0][0]']
#
#  Stack3_8x3_Conv (Conv2D)       (None, 14, 14, 1024  263168      ['Stack3_8x2_ReLU[0][0]']
#                                 )
#
#  Stack3_8x3_BN (BatchNormalizat  (None, 14, 14, 1024  4096       ['Stack3_8x3_Conv[0][0]']
#  ion)                           )
#
#  Stack3_8x3_Add (Add)           (None, 14, 14, 1024  0           ['Stack3_7x3_ReLU[0][0]',
#                                 )                                 'Stack3_8x3_BN[0][0]']
#
#  Stack3_8x3_ReLU (ReLU)         (None, 14, 14, 1024  0           ['Stack3_8x3_Add[0][0]']
#                                 )
#
#  Stack3_9x1_Conv (Conv2D)       (None, 14, 14, 256)  262400      ['Stack3_8x3_ReLU[0][0]']
#
#  Stack3_9x1_BN (BatchNormalizat  (None, 14, 14, 256)  1024       ['Stack3_9x1_Conv[0][0]']
#  ion)
#
#  Stack3_9x1_ReLU (ReLU)         (None, 14, 14, 256)  0           ['Stack3_9x1_BN[0][0]']
#
#  Stack3_9x2_Conv (Conv2D)       (None, 14, 14, 256)  590080      ['Stack3_9x1_ReLU[0][0]']
#
#  Stack3_9x2_BN (BatchNormalizat  (None, 14, 14, 256)  1024       ['Stack3_9x2_Conv[0][0]']
#  ion)
#
#  Stack3_9x2_ReLU (ReLU)         (None, 14, 14, 256)  0           ['Stack3_9x2_BN[0][0]']
#
#  Stack3_9x3_Conv (Conv2D)       (None, 14, 14, 1024  263168      ['Stack3_9x2_ReLU[0][0]']
#                                 )
#
#  Stack3_9x3_BN (BatchNormalizat  (None, 14, 14, 1024  4096       ['Stack3_9x3_Conv[0][0]']
#  ion)                           )
#
#  Stack3_9x3_Add (Add)           (None, 14, 14, 1024  0           ['Stack3_8x3_ReLU[0][0]',
#                                 )                                 'Stack3_9x3_BN[0][0]']
#
#  Stack3_9x3_ReLU (ReLU)         (None, 14, 14, 1024  0           ['Stack3_9x3_Add[0][0]']
#                                 )
#
#  Stack3_10x1_Conv (Conv2D)      (None, 14, 14, 256)  262400      ['Stack3_9x3_ReLU[0][0]']
#
#  Stack3_10x1_BN (BatchNormaliza  (None, 14, 14, 256)  1024       ['Stack3_10x1_Conv[0][0]']
#  tion)
#
#  Stack3_10x1_ReLU (ReLU)        (None, 14, 14, 256)  0           ['Stack3_10x1_BN[0][0]']
#
#  Stack3_10x2_Conv (Conv2D)      (None, 14, 14, 256)  590080      ['Stack3_10x1_ReLU[0][0]']
#
#  Stack3_10x2_BN (BatchNormaliza  (None, 14, 14, 256)  1024       ['Stack3_10x2_Conv[0][0]']
#  tion)
#
#  Stack3_10x2_ReLU (ReLU)        (None, 14, 14, 256)  0           ['Stack3_10x2_BN[0][0]']
#
#  Stack3_10x3_Conv (Conv2D)      (None, 14, 14, 1024  263168      ['Stack3_10x2_ReLU[0][0]']
#                                 )
#
#  Stack3_10x3_BN (BatchNormaliza  (None, 14, 14, 1024  4096       ['Stack3_10x3_Conv[0][0]']
#  tion)                          )
#
#  Stack3_10x3_Add (Add)          (None, 14, 14, 1024  0           ['Stack3_9x3_ReLU[0][0]',
#                                 )                                 'Stack3_10x3_BN[0][0]']
#
#  Stack3_10x3_ReLU (ReLU)        (None, 14, 14, 1024  0           ['Stack3_10x3_Add[0][0]']
#                                 )
#
#  Stack3_11x1_Conv (Conv2D)      (None, 14, 14, 256)  262400      ['Stack3_10x3_ReLU[0][0]']
#
#  Stack3_11x1_BN (BatchNormaliza  (None, 14, 14, 256)  1024       ['Stack3_11x1_Conv[0][0]']
#  tion)
#
#  Stack3_11x1_ReLU (ReLU)        (None, 14, 14, 256)  0           ['Stack3_11x1_BN[0][0]']
#
#  Stack3_11x2_Conv (Conv2D)      (None, 14, 14, 256)  590080      ['Stack3_11x1_ReLU[0][0]']
#
#  Stack3_11x2_BN (BatchNormaliza  (None, 14, 14, 256)  1024       ['Stack3_11x2_Conv[0][0]']
#  tion)
#
#  Stack3_11x2_ReLU (ReLU)        (None, 14, 14, 256)  0           ['Stack3_11x2_BN[0][0]']
#
#  Stack3_11x3_Conv (Conv2D)      (None, 14, 14, 1024  263168      ['Stack3_11x2_ReLU[0][0]']
#                                 )
#
#  Stack3_11x3_BN (BatchNormaliza  (None, 14, 14, 1024  4096       ['Stack3_11x3_Conv[0][0]']
#  tion)                          )
#
#  Stack3_11x3_Add (Add)          (None, 14, 14, 1024  0           ['Stack3_10x3_ReLU[0][0]',
#                                 )                                 'Stack3_11x3_BN[0][0]']
#
#  Stack3_11x3_ReLU (ReLU)        (None, 14, 14, 1024  0           ['Stack3_11x3_Add[0][0]']
#                                 )
#
#  Stack3_12x1_Conv (Conv2D)      (None, 14, 14, 256)  262400      ['Stack3_11x3_ReLU[0][0]']
#
#  Stack3_12x1_BN (BatchNormaliza  (None, 14, 14, 256)  1024       ['Stack3_12x1_Conv[0][0]']
# ...
#
#  Stack3_21x1_ReLU (ReLU)        (None, 14, 14, 256)  0           ['Stack3_21x1_BN[0][0]']
#
#  Stack3_21x2_Conv (Conv2D)      (None, 14, 14, 256)  590080      ['Stack3_21x1_ReLU[0][0]']
#
#  Stack3_21x2_BN (BatchNormaliza  (None, 14, 14, 256)  1024       ['Stack3_21x2_Conv[0][0]']
#  tion)
#
#  Stack3_21x2_ReLU (ReLU)        (None, 14, 14, 256)  0           ['Stack3_21x2_BN[0][0]']
#
#  Stack3_21x3_Conv (Conv2D)      (None, 14, 14, 1024  263168      ['Stack3_21x2_ReLU[0][0]']
#                                 )
#
#  Stack3_21x3_BN (BatchNormaliza  (None, 14, 14, 1024  4096       ['Stack3_21x3_Conv[0][0]']
#  tion)                          )
#
#  Stack3_21x3_Add (Add)          (None, 14, 14, 1024  0           ['Stack3_20x3_ReLU[0][0]',
#                                 )                                 'Stack3_21x3_BN[0][0]']
#
#  Stack3_21x3_ReLU (ReLU)        (None, 14, 14, 1024  0           ['Stack3_21x3_Add[0][0]']
#                                 )
#
#  Stack3_22x1_Conv (Conv2D)      (None, 14, 14, 256)  262400      ['Stack3_21x3_ReLU[0][0]']
#
#  Stack3_22x1_BN (BatchNormaliza  (None, 14, 14, 256)  1024       ['Stack3_22x1_Conv[0][0]']
#  tion)
#
#  Stack3_22x1_ReLU (ReLU)        (None, 14, 14, 256)  0           ['Stack3_22x1_BN[0][0]']
#
#  Stack3_22x2_Conv (Conv2D)      (None, 14, 14, 256)  590080      ['Stack3_22x1_ReLU[0][0]']
#
#  Stack3_22x2_BN (BatchNormaliza  (None, 14, 14, 256)  1024       ['Stack3_22x2_Conv[0][0]']
#  tion)
#
#  Stack3_22x2_ReLU (ReLU)        (None, 14, 14, 256)  0           ['Stack3_22x2_BN[0][0]']
#
#  Stack3_22x3_Conv (Conv2D)      (None, 14, 14, 1024  263168      ['Stack3_22x2_ReLU[0][0]']
#                                 )
#
#  Stack3_22x3_BN (BatchNormaliza  (None, 14, 14, 1024  4096       ['Stack3_22x3_Conv[0][0]']
#  tion)                          )
#
#  Stack3_22x3_Add (Add)          (None, 14, 14, 1024  0           ['Stack3_21x3_ReLU[0][0]',
#                                 )                                 'Stack3_22x3_BN[0][0]']
#
#  Stack3_22x3_ReLU (ReLU)        (None, 14, 14, 1024  0           ['Stack3_22x3_Add[0][0]']
#                                 )
#
#  Stack3_23x1_Conv (Conv2D)      (None, 14, 14, 256)  262400      ['Stack3_22x3_ReLU[0][0]']
#
#  Stack3_23x1_BN (BatchNormaliza  (None, 14, 14, 256)  1024       ['Stack3_23x1_Conv[0][0]']
#  tion)
#
#  Stack3_23x1_ReLU (ReLU)        (None, 14, 14, 256)  0           ['Stack3_23x1_BN[0][0]']
#
#  Stack3_23x2_Conv (Conv2D)      (None, 14, 14, 256)  590080      ['Stack3_23x1_ReLU[0][0]']
#
#  Stack3_23x2_BN (BatchNormaliza  (None, 14, 14, 256)  1024       ['Stack3_23x2_Conv[0][0]']
#  tion)
#
#  Stack3_23x2_ReLU (ReLU)        (None, 14, 14, 256)  0           ['Stack3_23x2_BN[0][0]']
#
#  Stack3_23x3_Conv (Conv2D)      (None, 14, 14, 1024  263168      ['Stack3_23x2_ReLU[0][0]']
#                                 )
#
#  Stack3_23x3_BN (BatchNormaliza  (None, 14, 14, 1024  4096       ['Stack3_23x3_Conv[0][0]']
#  tion)                          )
#
#  Stack3_23x3_Add (Add)          (None, 14, 14, 1024  0           ['Stack3_22x3_ReLU[0][0]',
#                                 )                                 'Stack3_23x3_BN[0][0]']
#
#  Stack3_23x3_ReLU (ReLU)        (None, 14, 14, 1024  0           ['Stack3_23x3_Add[0][0]']
#                                 )
#
#  Stack4_1x1_Conv (Conv2D)       (None, 7, 7, 512)    524800      ['Stack3_23x3_ReLU[0][0]']
#
#  Stack4_1x1_BN (BatchNormalizat  (None, 7, 7, 512)   2048        ['Stack4_1x1_Conv[0][0]']
#  ion)
#
#  Stack4_1x1_ReLU (ReLU)         (None, 7, 7, 512)    0           ['Stack4_1x1_BN[0][0]']
#
#  Stack4_1x2_Conv (Conv2D)       (None, 7, 7, 512)    2359808     ['Stack4_1x1_ReLU[0][0]']
#
#  Stack4_1x2_BN (BatchNormalizat  (None, 7, 7, 512)   2048        ['Stack4_1x2_Conv[0][0]']
#  ion)
#
#  Stack4_1x2_ReLU (ReLU)         (None, 7, 7, 512)    0           ['Stack4_1x2_BN[0][0]']
#
#  Stack4_1x0_SC_Conv (Conv2D)    (None, 7, 7, 2048)   2099200     ['Stack3_23x3_ReLU[0][0]']
#
#  Stack4_1x3_Conv (Conv2D)       (None, 7, 7, 2048)   1050624     ['Stack4_1x2_ReLU[0][0]']
#
#  Stack4_1x0_SC_BN (BatchNormali  (None, 7, 7, 2048)  8192        ['Stack4_1x0_SC_Conv[0][0]']
#  zation)
#
#  Stack4_1x3_BN (BatchNormalizat  (None, 7, 7, 2048)  8192        ['Stack4_1x3_Conv[0][0]']
#  ion)
#
#  Stack4_1x3_Add (Add)           (None, 7, 7, 2048)   0           ['Stack4_1x0_SC_BN[0][0]',
#                                                                   'Stack4_1x3_BN[0][0]']
#
#  Stack4_1x3_ReLU (ReLU)         (None, 7, 7, 2048)   0           ['Stack4_1x3_Add[0][0]']
#
#  Stack4_2x1_Conv (Conv2D)       (None, 7, 7, 512)    1049088     ['Stack4_1x3_ReLU[0][0]']
#
#  Stack4_2x1_BN (BatchNormalizat  (None, 7, 7, 512)   2048        ['Stack4_2x1_Conv[0][0]']
#  ion)
#
#  Stack4_2x1_ReLU (ReLU)         (None, 7, 7, 512)    0           ['Stack4_2x1_BN[0][0]']
#
#  Stack4_2x2_Conv (Conv2D)       (None, 7, 7, 512)    2359808     ['Stack4_2x1_ReLU[0][0]']
#
#  Stack4_2x2_BN (BatchNormalizat  (None, 7, 7, 512)   2048        ['Stack4_2x2_Conv[0][0]']
#  ion)
#
#  Stack4_2x2_ReLU (ReLU)         (None, 7, 7, 512)    0           ['Stack4_2x2_BN[0][0]']
#
#  Stack4_2x3_Conv (Conv2D)       (None, 7, 7, 2048)   1050624     ['Stack4_2x2_ReLU[0][0]']
#
#  Stack4_2x3_BN (BatchNormalizat  (None, 7, 7, 2048)  8192        ['Stack4_2x3_Conv[0][0]']
#  ion)
#
#  Stack4_2x3_Add (Add)           (None, 7, 7, 2048)   0           ['Stack4_1x3_ReLU[0][0]',
#                                                                   'Stack4_2x3_BN[0][0]']
#
#  Stack4_2x3_ReLU (ReLU)         (None, 7, 7, 2048)   0           ['Stack4_2x3_Add[0][0]']
#
#  Stack4_3x1_Conv (Conv2D)       (None, 7, 7, 512)    1049088     ['Stack4_2x3_ReLU[0][0]']
#
#  Stack4_3x1_BN (BatchNormalizat  (None, 7, 7, 512)   2048        ['Stack4_3x1_Conv[0][0]']
#  ion)
#
#  Stack4_3x1_ReLU (ReLU)         (None, 7, 7, 512)    0           ['Stack4_3x1_BN[0][0]']
#
#  Stack4_3x2_Conv (Conv2D)       (None, 7, 7, 512)    2359808     ['Stack4_3x1_ReLU[0][0]']
#
#  Stack4_3x2_BN (BatchNormalizat  (None, 7, 7, 512)   2048        ['Stack4_3x2_Conv[0][0]']
#  ion)
#
#  Stack4_3x2_ReLU (ReLU)         (None, 7, 7, 512)    0           ['Stack4_3x2_BN[0][0]']
#
#  Stack4_3x3_Conv (Conv2D)       (None, 7, 7, 2048)   1050624     ['Stack4_3x2_ReLU[0][0]']
#
#  Stack4_3x3_BN (BatchNormalizat  (None, 7, 7, 2048)  8192        ['Stack4_3x3_Conv[0][0]']
#  ion)
#
#  Stack4_3x3_Add (Add)           (None, 7, 7, 2048)   0           ['Stack4_2x3_ReLU[0][0]',
#                                                                   'Stack4_3x3_BN[0][0]']
#
#  Stack4_3x3_ReLU (ReLU)         (None, 7, 7, 2048)   0           ['Stack4_3x3_Add[0][0]']
#
#  Tail_GlobalAVGPool (GlobalAver  (None, 2048)        0           ['Stack4_3x3_ReLU[0][0]']
#  agePooling2D)
#
#  Tail_Flatten (Flatten)         (None, 2048)         0           ['Tail_GlobalAVGPool[0][0]']
#
#  Tail_Dense (Dense)             (None, 1000)         2049000     ['Tail_Flatten[0][0]']
#
# ==================================================================================================
# Total params: 44,706,920
# Trainable params: 44,601,704
# Non-trainable params: 105,216
# __________________________________________________________________________________________________
